# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('myntra_products_catalog.csv')

# %%
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
#  3   Gender        12491 non-null  object
#  4   Price (INR)   12491 non-null  int64
#  5   NumImages     12491 non-null  int64
#  6   Description   12491 non-null  object
#  7   PrimaryColor  11597 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 780.8+ KB

# %%
df.isnull().sum()
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# dtype: int64

# %%
print(df['Gender'].to_string())
# Out:
# 0             Unisex
# 1              Women
# 2              Women
# 3                Men
# 4                Men
# 5                Men
# 6                Men
# 7              Women
# 8                Men
# 9             Unisex
# 10             Women
# 11               Men
# 12               Men
# 13             Women
# 14               Men
# 15               Men
# 16            Unisex
# 17            Unisex
# 18               Men
# 19             Women
# 20             Women
# 21               Men
# 22            Unisex
# 23             Women
# 24               Men
# 25               Men
# 26            Unisex
# 27               Men
# 28              Boys
# 29            Unisex
# 30             Women
# 31             Women
# 32               Men
# 33             Women
# 34               Men
# 35               Men
# 36               Men
# 37               Men
# 38             Women
# 39             Women
# 40               Men
# 41             Women
# 42               Men
# ...

# %%
print(df['Gender'].head(10))
# Out:
# 0    Unisex
# 1     Women
# 2     Women
# 3       Men
# 4       Men
# 5       Men
# 6       Men
# 7     Women
# 8       Men
# 9    Unisex
# Name: Gender, dtype: object

# %%
df['PrimaryColor'] = df['PrimaryColor'].fillna('Others')
print(df['PrimaryColor'].to_string())
# Out:
# 0            Black
# 1            Beige
# 2             Pink
# 3             Blue
# 4            White
# 5            Brown
# 6             Blue
# 7         Burgundy
# 8              Red
# 9            Black
# 10            Blue
# 11           Green
# 12          Others
# 13          Maroon
# 14             Red
# 15            Navy
# 16           White
# 17            Blue
# 18           Brown
# 19             Red
# 20          Others
# 21           Black
# 22             Red
# 23            Blue
# 24            Gold
# 25           Brown
# 26             Red
# 27            Blue
# 28            Blue
# 29          Others
# 30            Blue
# 31            Pink
# 32            Blue
# 33            Blue
# 34           Brown
# 35            Blue
# 36            Blue
# 37            Blue
# 38           White
# 39          Others
# 40            Blue
# 41           Brown
# 42           Beige
# 43            Blue
# 44            Blue
# 45             Red
# 46           Black
# ...

# %%
df = df.applymap(lambda n:n.upper() if type(n) == str else n)

# %%
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY UNISEX BLACK & GREY PRINTED MEDIUM TROLLE...
# 1       10016283  ETHNOVOGUE WOMEN BEIGE & GREY MADE TO MEASURE ...
# 2       10009781  SPYKAR WOMEN PINK ALEXA SUPER SKINNY FIT HIGH-...
# 3       10015921  RAYMOND MEN BLUE SELF-DESIGN SINGLE-BREASTED B...
# 4       10017833  PARX MEN BROWN & OFF-WHITE SLIM FIT PRINTED CA...
# ...          ...                                                ...
# 12486   10262843  PEPE JEANS MEN BLACK HAMMOCK SLIM FIT LOW-RISE...
# 12487   10261721                 MOCHI WOMEN GOLD-TONED SOLID HEELS
# 12488   10261607  612 LEAGUE GIRLS NAVY BLUE & WHITE PRINTED REG...
# 12489   10266621  BVLGARI MEN AQVA POUR HOMME MARINE EAU DE TOIL...
# 12490   10265199  PEPE JEANS MEN BLACK & GREY STRIPED POLO COLLA...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  UNISEX        11745          7
# ...

# %%
df['ProductBrand'] = df['ProductBrand'].str.lstrip()

# %%
print(df['ProductBrand'].to_string())
# Out:
# 0                                DKNY
# 1                          ETHNOVOGUE
# 2                              SPYKAR
# 3                             RAYMOND
# 4                                PARX
# 5                             SHOWOFF
# 6                                PARX
# 7                              SPYKAR
# 8                                PARX
# 9                                DKNY
# 10                       KENNETH COLE
# 11                               PARX
# 12                             POLICE
# 13                            VISHUDH
# 14                               PARX
# 15                        BEING HUMAN
# 16                           HOMESAKE
# 17                 SEJ BY NISHA GUPTA
# 18                            YAK YAK
# 19                            PARFAIT
# 20                       MICHAEL KORS
# 21                         HIGHLANDER
# 22                 SEJ BY NISHA GUPTA
# 23                             SPYKAR
# 24                     JEWEL JUNCTION
# ...

# %%
print('Varrious Brands available:', df.ProductBrand.unique())
# Out:
# Varrious Brands available: ['DKNY' 'ETHNOVOGUE' 'SPYKAR' 'RAYMOND' 'PARX' 'SHOWOFF' 'KENNETH COLE'
#  'POLICE' 'VISHUDH' 'BEING HUMAN' 'HOMESAKE' 'SEJ BY NISHA GUPTA'
#  'YAK YAK' 'PARFAIT' 'MICHAEL KORS' 'HIGHLANDER' 'JEWEL JUNCTION' 'ID'
#  'STORY@HOME' 'GINI AND JONY' 'SERA' 'ACCESSHER' 'ALCIS'
#  'DIFFERENCE OF OPINION' 'TOKYO TALKIES' 'ANNA SUI' 'HER BY INVICTUS'
#  'SOIE' 'LARA KAREN' 'URBAN DOG' 'AHILYA' 'VASTRAMAY' 'CAMPUS SUTRA'
#  'FIDO DIDO' 'MIAH DECOR' 'BUCKLEUP' 'PETER ENGLAND' 'AIGNER' 'LADY LYKA'
#  'PARK AVENUE' 'ROADSTER' 'U.S. POLO ASSN. DENIM CO.' 'SWEET DREAMS'
#  'KAZO' 'STYLO BUG' 'BVLGARI' 'QRAA MEN' 'GAS' 'WITH' 'ZUSH'
#  'JBN CREATION' 'U.S. POLO ASSN. KIDS' 'DRESSBERRY' 'COLORPLUS' 'LAKME'
#  'ALLEN SOLLY WOMAN' 'PALM TREE' 'ARROW' 'DAVID BECKHAM' 'MANGO' 'CARRERA'
#  'ROMEE' 'TAYHAA' 'ISHIN' 'SHOE COUTURE' 'HARBORNBAY' 'KEDS' 'ROZIA'
#  'AJ DEZINES' 'MONTE CARLO' 'EVEN' 'ETHER' 'CRIMSOUNE CLUB'
# ...

# %%
unique_brand = len(pd.unique(df['ProductBrand']))

# %%
print (unique_brand)
# Out:
# 677

# %%
df2=df['Gender'].unique()

# %%
print(df2)
# Out:
# ['UNISEX' 'WOMEN' 'MEN' 'BOYS' 'GIRLS' 'UNISEX KIDS']

# %%
print('Categories in PrimaryColor:',df['PrimaryColor'].unique())
# Out:
# Categories in PrimaryColor: [' BLACK' ' BEIGE' ' PINK' 'BLUE' ' WHITE' ' BROWN' ' BURGUNDY' ' RED'
#  ' GREEN' 'OTHERS' ' MAROON' ' NAVY' ' GOLD' ' YELLOW' ' GREY' ' PLATINUM'
#  ' SILVER' ' KHAKI' ' MUSTARD' ' LAVENDER' ' MATTE' ' ROSE' ' CHARCOAL'
#  ' PURPLE' ' ORANGE' ' PEACH' ' MAGENTA' ' BRONZE']

# %%
#df = ('Price Rang Available:', df['Price (INR)'])

# %%
#df
# Out:
# ('Price Rang Available:',
#  0        11745
#  1         5810
#  2          899
#  3         5599
#  4          759
#           ...
#  12486     1299
#  12487     1990
#  12488      602
#  12489     8950
#  12490      799
#  Name: Price (INR), Length: 12491, dtype: int64)

# %%
print('Max Price:', df['Price (INR)'].max())
# Out:
# Max Price: 63090

# %%
print('Min Price:', df['Price (INR)'].min())
# Out:
# Min Price: 90

# %%
print('Mean Price:', df['Price (INR)'].mean())
# Out:
# Mean Price: 1452.6609558882396

# %%
df.ProductBrand.value_counts()[ :10].plot(kind = 'bar', title = 'Top 10 Brands', color ='brown')
# Out:
# <AxesSubplot:title={'center':'Top 10 Brands'}>

# %%
df1 = df.groupby('ProductBrand')['Price (INR)'].mean().sort_values(ascending = False).head(10)

# %%
df1.plot(kind = 'bar' , color = 'orange')
# Out:
# <AxesSubplot:xlabel='ProductBrand'>

# %%
pie=df.groupby('Gender')['ProductID'].count()

# %%
pie.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='ProductID'>
